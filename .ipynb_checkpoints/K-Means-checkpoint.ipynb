# %% [markdown]
# # Part 1

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
X = np.array([[1, 2], [1, 4], [1, 0], 
              [4, 2], [4, 4], [4, 0]])
print(X)
# Out:
# [[1 2]
#  [1 4]
#  [1 0]
#  [4 2]
#  [4 4]
#  [4 0]]

# %%
Y = pd.DataFrame(X,columns=["A","B"])
print(Y)
# Out:
#    A  B
# 0  1  2
# 1  1  4
# 2  1  0
# 3  4  2
# 4  4  4
# 5  4  0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(Y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([0, 1, 0, 1, 1, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[2.        , 0.66666667],
#        [3.        , 3.33333333]])

# %%
Y['cluster_id'] = kmeans.labels_

# %%
Y
# Out:
#    A  B  cluster_id
# 0  1  2           0
# 1  1  4           1
# 2  1  0           0
# 3  4  2           1
# 4  4  4           1
# 5  4  0           0

# %%
kmeans.inertia_
# Out:
# 17.333333333333332

# %%
kmeans.predict([[0,0],[4,4]])
# Out:
# array([0, 1])

# %%
Y.plot(kind='scatter',x='A',y='B')

# %% [markdown]
# # Part -2

# %%
cereal_df = pd.read_csv("Cereals.csv",index_col='name')

# %%
cereal_df.head()
# Out:
#                            calories  protein  fat  sodium  fiber  carbo  \
# name
# 100%_Bran                        70        4    1     130   10.0    5.0
# 100%_Natural_Bran               120        3    5      15    2.0    8.0
# All-Bran                         70        4    1     260    9.0    7.0
# All-Bran_with_Extra_Fiber        50        4    0     140   14.0    8.0
# Almond_Delight                  110        2    2     200    1.0   14.0
#
#                            sugars  potass  vitamins  shelf  weight  cups  \
# name
# 100%_Bran                     6.0   280.0        25      3     1.0  0.33
# 100%_Natural_Bran             8.0   135.0         0      3     1.0  1.00
# All-Bran                      5.0   320.0        25      3     1.0  0.33
# All-Bran_with_Extra_Fiber     0.0   330.0        25      3     1.0  0.50
# Almond_Delight                8.0     NaN        25      3     1.0  0.75
#
#                               rating
# name
# 100%_Bran                  68.402973
# 100%_Natural_Bran          33.983679
# All-Bran                   59.425505
# All-Bran_with_Extra_Fiber  93.704912
# Almond_Delight             34.384843

# %%
cereal_df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   75.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   28.246753   2.207792   1.029610   0.821039
# std     4.378656   70.410636   22.342523   0.832524   0.150477   0.232716
# min     0.000000   15.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   42.500000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
cereal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100%_Bran to Wheaties_Honey_Gold
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  77 non-null     int64
#  1   protein   77 non-null     int64
#  2   fat       77 non-null     int64
#  3   sodium    77 non-null     int64
#  4   fiber     77 non-null     float64
#  5   carbo     76 non-null     float64
#  6   sugars    76 non-null     float64
#  7   potass    75 non-null     float64
#  8   vitamins  77 non-null     int64
#  9   shelf     77 non-null     int64
#  10  weight    77 non-null     float64
#  11  cups      77 non-null     float64
#  12  rating    77 non-null     float64
# dtypes: float64(7), int64(6)
# memory usage: 8.4+ KB

# %%
cereal_df.isnull().sum()
# Out:
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer()

# %%
imputer.fit(cereal_df)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
cereal_df = pd.DataFrame(imputer.transform(cereal_df),columns=cereal_df.columns,index=cereal_df.index)

# %%
cereal_df.isnull().sum()
# Out:
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
cereal_df.head(10)
# Out:
#                            calories  protein  fat  sodium  fiber  carbo  \
# name
# 100%_Bran                      70.0      4.0  1.0   130.0   10.0    5.0
# 100%_Natural_Bran             120.0      3.0  5.0    15.0    2.0    8.0
# All-Bran                       70.0      4.0  1.0   260.0    9.0    7.0
# All-Bran_with_Extra_Fiber      50.0      4.0  0.0   140.0   14.0    8.0
# Almond_Delight                110.0      2.0  2.0   200.0    1.0   14.0
# Apple_Cinnamon_Cheerios       110.0      2.0  2.0   180.0    1.5   10.5
# Apple_Jacks                   110.0      2.0  0.0   125.0    1.0   11.0
# Basic_4                       130.0      3.0  2.0   210.0    2.0   18.0
# Bran_Chex                      90.0      2.0  1.0   200.0    4.0   15.0
# Bran_Flakes                    90.0      3.0  0.0   210.0    5.0   13.0
#
#                            sugars      potass  vitamins  shelf  weight  cups  \
# name
# 100%_Bran                     6.0  280.000000      25.0    3.0    1.00  0.33
# 100%_Natural_Bran             8.0  135.000000       0.0    3.0    1.00  1.00
# All-Bran                      5.0  320.000000      25.0    3.0    1.00  0.33
# All-Bran_with_Extra_Fiber     0.0  330.000000      25.0    3.0    1.00  0.50
# Almond_Delight                8.0   98.666667      25.0    3.0    1.00  0.75
# Apple_Cinnamon_Cheerios      10.0   70.000000      25.0    1.0    1.00  0.75
# Apple_Jacks                  14.0   30.000000      25.0    2.0    1.00  1.00
# Basic_4                       8.0  100.000000      25.0    3.0    1.33  0.75
# Bran_Chex                     6.0  125.000000      25.0    1.0    1.00  0.67
# Bran_Flakes                   5.0  190.000000      25.0    3.0    1.00  0.67
#
#                               rating
# name
# 100%_Bran                  68.402973
# 100%_Natural_Bran          33.983679
# All-Bran                   59.425505
# All-Bran_with_Extra_Fiber  93.704912
# Almond_Delight             34.384843
# Apple_Cinnamon_Cheerios    29.509541
# Apple_Jacks                33.174094
# Basic_4                    37.038562
# Bran_Chex                  49.120253
# Bran_Flakes                53.313813

# %%
cereal_df = cereal_df.drop(['rating','shelf'],axis=1)

# %%
cereal_df.tail(10)
# Out:
#                          calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Special_K                   110.0      6.0  0.0   230.0    1.0   16.0     3.0
# Strawberry_Fruit_Wheats      90.0      2.0  0.0    15.0    3.0   15.0     5.0
# Total_Corn_Flakes           110.0      2.0  1.0   200.0    0.0   21.0     3.0
# Total_Raisin_Bran           140.0      3.0  1.0   190.0    4.0   15.0    14.0
# Total_Whole_Grain           100.0      3.0  1.0   200.0    3.0   16.0     3.0
# Triples                     110.0      2.0  1.0   250.0    0.0   21.0     3.0
# Trix                        110.0      1.0  1.0   140.0    0.0   13.0    12.0
# Wheat_Chex                  100.0      3.0  1.0   230.0    3.0   17.0     3.0
# Wheaties                    100.0      3.0  1.0   200.0    3.0   17.0     3.0
# Wheaties_Honey_Gold         110.0      2.0  1.0   200.0    1.0   16.0     8.0
#
#                          potass  vitamins  weight     rating
# name
# Special_K                  55.0      25.0     1.0  53.131324
# Strawberry_Fruit_Wheats    90.0      25.0     1.0  59.363993
# Total_Corn_Flakes          35.0     100.0     1.0  38.839746
# Total_Raisin_Bran         230.0     100.0     1.5  28.592785
# Total_Whole_Grain         110.0     100.0     1.0  46.658844
# Triples                    60.0      25.0     1.0  39.106174
# Trix                       25.0      25.0     1.0  27.753301
# Wheat_Chex                115.0      25.0     1.0  49.787445
# Wheaties                  110.0      25.0     1.0  51.592193
# Wheaties_Honey_Gold        60.0      25.0     1.0  36.187559

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_clusters':list(range(2,10))}

# %%
kmeans1 = KMeans()

# %%
gs_object = GridSearchCV(kmeans1,param_grid,verbose=15,n_jobs=-1)

# %%
gs_object.fit(cereal_df)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1983s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  40 | elapsed:    2.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  36 out of  40 | elapsed:    2.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    2.9s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=KMeans(algorithm='auto', copy_x=True, init='k-means++',
#                               max_iter=300, n_clusters=8, n_init=10,
#                               n_jobs=None, precompute_distances='auto',
#                               random_state=None, tol=0.0001, verbose=0),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'n_clusters': [2, 3, 4, 5, 6, 7, 8, 9]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=15)

# %%
gs_object.best_estimator_
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
cereal_df['Category'] = gs_object.predict(cereal_df)

# %%
cereal_df
# Out:
#                            calories  protein  fat  sodium  fiber  carbo  \
# name
# 100%_Bran                      70.0      4.0  1.0   130.0   10.0    5.0
# 100%_Natural_Bran             120.0      3.0  5.0    15.0    2.0    8.0
# All-Bran                       70.0      4.0  1.0   260.0    9.0    7.0
# All-Bran_with_Extra_Fiber      50.0      4.0  0.0   140.0   14.0    8.0
# Almond_Delight                110.0      2.0  2.0   200.0    1.0   14.0
# ...                             ...      ...  ...     ...    ...    ...
# Triples                       110.0      2.0  1.0   250.0    0.0   21.0
# Trix                          110.0      1.0  1.0   140.0    0.0   13.0
# Wheat_Chex                    100.0      3.0  1.0   230.0    3.0   17.0
# Wheaties                      100.0      3.0  1.0   200.0    3.0   17.0
# Wheaties_Honey_Gold           110.0      2.0  1.0   200.0    1.0   16.0
#
#                            sugars      potass  vitamins  weight     rating  \
# name
# 100%_Bran                     6.0  280.000000      25.0     1.0  68.402973
# 100%_Natural_Bran             8.0  135.000000       0.0     1.0  33.983679
# All-Bran                      5.0  320.000000      25.0     1.0  59.425505
# All-Bran_with_Extra_Fiber     0.0  330.000000      25.0     1.0  93.704912
# Almond_Delight                8.0   98.666667      25.0     1.0  34.384843
# ...                           ...         ...       ...     ...        ...
# Triples                       3.0   60.000000      25.0     1.0  39.106174
# Trix                         12.0   25.000000      25.0     1.0  27.753301
# Wheat_Chex                    3.0  115.000000      25.0     1.0  49.787445
# Wheaties                      3.0  110.000000      25.0     1.0  51.592193
# Wheaties_Honey_Gold           8.0   60.000000      25.0     1.0  36.187559
#
#                            Category
# name
# 100%_Bran                         6
# 100%_Natural_Bran                 1
# All-Bran                          6
# All-Bran_with_Extra_Fiber         6
# Almond_Delight                    0
# ...                             ...
# Triples                           7
# Trix                              5
# Wheat_Chex                        0
# Wheaties                          0
# Wheaties_Honey_Gold               2
#
# [77 rows x 12 columns]

# %%
cereal_df.Category.value_counts(sort=False).plot(kind='bar')

# %%
cat_name_dict = {}
for i in range(8):
    cat_name_dict[i] = list(cereal_df[cereal_df.Category==i].index)

# %%
cat_name_dict
# Out:
# {0: ['Almond_Delight',
#   'Basic_4',
#   'Bran_Chex',
#   'Honey_Nut_Cheerios',
#   'Multi-Grain_Cheerios',
#   'Nutri-Grain_Almond-Raisin',
#   'Total_Whole_Grain',
#   'Wheat_Chex',
#   'Wheaties'],
#  1: ['100%_Natural_Bran',
#   'Frosted_Mini-Wheats',
#   'Maypo',
#   'Puffed_Rice',
#   'Puffed_Wheat',
#   'Quaker_Oatmeal',
#   'Raisin_Squares',
#   'Shredded_Wheat',
#   "Shredded_Wheat_'n'Bran",
#   'Shredded_Wheat_spoon_size',
#   'Strawberry_Fruit_Wheats'],
#  2: ['Apple_Cinnamon_Cheerios',
#   "Cap'n'Crunch",
#   'Cinnamon_Toast_Crunch',
#   'Cocoa_Puffs',
#   'Count_Chocula',
#   'Crispix',
#   'Double_Chex',
#   'Frosted_Flakes',
#   'Honey_Graham_Ohs',
#   'Honey-comb',
#   'Just_Right_Crunchy__Nuggets',
#   'Lucky_Charms',
#   'Nut&Honey_Crunch',
#   'Special_K',
#   'Total_Corn_Flakes',
#   'Wheaties_Honey_Gold'],
#  3: ['Bran_Flakes',
#   'Fruit_&_Fibre_Dates,_Walnuts,_and_Oats',
#   'Fruitful_Bran',
#   'Post_Nat._Raisin_Bran',
#   'Raisin_Bran',
#   'Total_Raisin_Bran'],
#  4: ['Clusters',
#   "Cracklin'_Oat_Bran",
#   'Cream_of_Wheat_(Quick)',
#   'Crispy_Wheat_&_Raisins',
#   'Grape_Nuts_Flakes',
#   'Grape-Nuts',
#   'Great_Grains_Pecan',
#   'Just_Right_Fruit_&_Nut',
#   'Life',
#   'Muesli_Raisins,_Dates,_&_Almonds',
#   'Muesli_Raisins,_Peaches,_&_Pecans',
#   'Mueslix_Crispy_Blend',
#   'Nutri-grain_Wheat',
#   'Oatmeal_Raisin_Crisp',
#   'Quaker_Oat_Squares',
#   'Raisin_Nut_Bran'],
#  5: ['Apple_Jacks',
#   'Corn_Pops',
#   'Froot_Loops',
#   'Fruity_Pebbles',
#   'Golden_Crisp',
#   'Smacks',
#   'Trix'],
#  6: ['100%_Bran', 'All-Bran', 'All-Bran_with_Extra_Fiber'],
#  7: ['Cheerios',
#   'Corn_Chex',
#   'Corn_Flakes',
#   'Golden_Grahams',
#   'Kix',
#   'Product_19',
#   'Rice_Chex',
#   'Rice_Krispies',
#   'Triples']}
